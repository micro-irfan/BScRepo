# %%
import pandas as pd

# %%
G2 = pd.read_csv('python for fun.csv', sep=';')

# %%
G2['Phospholipid Group'] = G2['Group'].apply(lambda title: title.split(' ')[0])

# %%
G2['Number'] = G2.Group.str[3:]

# %%
G3 = G2.set_index(['Phospholipid Group', 'Number']).drop(['Group'], axis=1)

# %%
G4 = G5.transpose()

# %%
G5.head()
# Out:
#          M Bovis BCG  M Bovis BCG.1  M Bovis BCG.2  M. Ulcerans  \
# Group
# PA 32:0     0.003786       0.003249       0.005842     0.000403
# PA 32:1     0.002100       0.002538       0.002548     0.000652
# PA 32:2     0.000115       0.000125       0.000197     0.000153
# PA 33:0     0.001550       0.001174       0.001483     0.000361
# PA 33:1     0.000622       0.000872       0.000804     0.000214
#
#          M. Ulcerans.1  M. Ulcerans.2  M. Ulcerans.3  M. Ulcerans.4  \
# Group
# PA 32:0       0.000286       0.000277       0.000299       0.000257
# PA 32:1       0.000447       0.000393       0.000163       0.000165
# PA 32:2       0.000059       0.000096       0.000033       0.000023
# PA 33:0       0.000223       0.000210       0.000103       0.000118
# PA 33:1       0.000281       0.000151       0.000022       0.000068
#
#          M. Ulcerans.5   A. Baum     ...      A. Baum.2  A. Baum.3  A. Baum.4  \
# Group                                ...
# ...

# %%
G4.head()
# Out:
# Group           PA 32:0   PA 32:1   PA 32:2   PA 33:0   PA 33:1   PA 34:0  \
# M Bovis BCG    0.003786  0.002100  0.000115  0.001550  0.000622  0.006050
# M Bovis BCG.1  0.003249  0.002538  0.000125  0.001174  0.000872  0.006047
# M Bovis BCG.2  0.005842  0.002548  0.000197  0.001483  0.000804  0.008876
# M. Ulcerans    0.000403  0.000652  0.000153  0.000361  0.000214  0.000898
# M. Ulcerans.1  0.000286  0.000447  0.000059  0.000223  0.000281  0.000819
#
# Group           PA 34:1   PA 35:0   PA 35:1   PA 36:0    ...      PI 33:0  \
# M Bovis BCG    0.009028  0.004571  0.001258  0.005488    ...     0.010108
# M Bovis BCG.1  0.009555  0.003786  0.001376  0.005356    ...     0.007400
# M Bovis BCG.2  0.010774  0.004444  0.001256  0.008621    ...     0.010717
# M. Ulcerans    0.002363  0.002893  0.000734  0.004843    ...     0.022116
# M. Ulcerans.1  0.001717  0.002120  0.000765  0.003515    ...     0.024827
#
# ...

# %%
G5 = G2.set_index('Group')

# %%
G4.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %%
df = pd.read_csv('Excel_Sample 1.csv', sep= ';')

# %%
#df.set_index('Phospholipid Group')

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(G4)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_data = scaler.transform(G4)

# %%
# PCA
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca.fit(scaled_data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.components_
# Out:
# array([[ 0.07151438,  0.02225524, -0.14656095,  0.09192161,  0.07923147,
#          0.08525594,  0.02535863,  0.13070051,  0.11934227,  0.15974781,
#          0.08426425, -0.12496642,  0.16684253,  0.07882187, -0.17783948,
#          0.10837302,  0.14170087,  0.086717  , -0.17395925,  0.16095691,
#          0.17263096,  0.14795657,  0.16941427,  0.12214748, -0.17893725,
#         -0.17892236, -0.16700883, -0.1794745 , -0.17945853, -0.17913735,
#          0.06797586, -0.16075268, -0.15120424, -0.17844166,  0.14400717,
#          0.15216579,  0.11061338,  0.17394278,  0.15047159,  0.167661  ,
#          0.14658394,  0.16482289,  0.13982813,  0.14353653,  0.16513861,
#          0.14537451,  0.15719981,  0.14313844,  0.14512667],
#        [ 0.22942499,  0.25121544,  0.05291141,  0.22092675,  0.22550772,
#          0.22244853,  0.25244806,  0.16311824,  0.17726595,  0.10264081,
#          0.20636063,  0.12133312, -0.05518743,  0.23115586, -0.02583611,
# ...

# %%
x_pca = pca.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (21, 49)

# %%
x_pca.shape
# Out:
# (21, 2)

# %%
import matplotlib.pyplot as plt

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-93ddce39d6eb> in <module>()
# ----> 1 G4.columns()
#
# TypeError: 'MultiIndex' object is not callable

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1])
plt.xlabel('First Principle Component')
plt.ylabel('Second Principle Component')
# Out:
# Text(0, 0.5, 'Second Principle Component')

# %%
df_comp = pd.DataFrame(pca.components_)

# %%
import seaborn as sns

# %%
heading = pd.read_csv('Heading.csv', sep=';')

# %%
heading.head()
# Out:
#    Heading
# 0  PA 32:0
# 1  PA 32:1
# 2  PA 32:2
# 3  PA 33:0
# 4  PA 33:1

# %%
df_comp = pd.DataFrame(pca.components_, columns = heading['Heading'])

# %%
plt.figure(figsize=(18,6))
sns.heatmap(df_comp,cmap='plasma')

# %%
sns.scatterplot(df_comp,)
# Out:
# Phospholipid Group        PA                                          \
# Number                  32:0      32:1      32:2      33:0      33:1
# M Bovis BCG         0.003786  0.002100  0.000115  0.001550  0.000622
# M Bovis BCG.1       0.003249  0.002538  0.000125  0.001174  0.000872
# M Bovis BCG.2       0.005842  0.002548  0.000197  0.001483  0.000804
# M. Ulcerans         0.000403  0.000652  0.000153  0.000361  0.000214
# M. Ulcerans.1       0.000286  0.000447  0.000059  0.000223  0.000281
# M. Ulcerans.2       0.000277  0.000393  0.000096  0.000210  0.000151
# M. Ulcerans.3       0.000299  0.000163  0.000033  0.000103  0.000022
# M. Ulcerans.4       0.000257  0.000165  0.000023  0.000118  0.000068
# M. Ulcerans.5       0.000278  0.000164  0.000028  0.000110  0.000045
# A. Baum             0.000119  0.000398  0.000153  0.000014  0.000087
# A. Baum.1           0.000102  0.000376  0.000139  0.000011  0.000077
# A. Baum.2           0.000102  0.000326  0.000131  0.000013  0.000075
# ...

# %%
PCA2 = pd.read_csv('Phospholipid head for PCA.csv', sep = ';')

# %%
PCA23 = PCA2.transpose()

# %%
PCA23.head()
# Out:
#                  0             1             2            3            4   \
# Group  M. bovis BCG  M. bovis BCG  M. bovis BCG  M. ulcerans  M. ulcerans
# PA        0.0382545     0.0375413     0.0491539    0.0170685    0.0127354
# PE          0.71907      0.795431       0.72384      0.32506     0.324999
# PG        0.0534241     0.0328661     0.0291565   0.00587717   0.00556686
# PI         0.189252      0.134161       0.19785     0.651994     0.656699
#
#                 5            6            7            8            9   \
# Group  M. ulcerans  M. ulcerans  M. ulcerans  M. ulcerans  A. baumanii
# PA       0.0120531    0.0101695     0.010918    0.0105438   0.00360677
# PE        0.260898     0.350556     0.321533     0.336045     0.254708
# PG      0.00620484   0.00967205   0.00989778   0.00978492     0.741685
# PI        0.720844     0.629602     0.657651     0.643627            0
#
#           ...                11           12           13           14  \
# ...
